# %%
# to fix
#   what happened to 'party' in merged data?
#   party vs candidate_party? what is 'democrat', 'republican'?
#   change case to match other years' datasets
import pandas as pd
filename = 'data/2016-precinct-house.tab'
df_h16 = pd.read_csv(filename)
filename = 'data/2016-precinct-senate.csv'
df_s16 = pd.read_csv(filename)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (13,19,27,30,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_h16.head(25)
# Out:
#     year stage  special    state state_postal  state_fips  state_icpsr  \
# 0   2016   gen    False  Alabama           AL           1           41
# 1   2016   gen    False  Alabama           AL           1           41
# 2   2016   gen    False  Alabama           AL           1           41
# 3   2016   gen    False  Alabama           AL           1           41
# 4   2016   gen    False  Alabama           AL           1           41
# 5   2016   gen    False  Alabama           AL           1           41
# 6   2016   gen    False  Alabama           AL           1           41
# 7   2016   gen    False  Alabama           AL           1           41
# 8   2016   gen    False  Alabama           AL           1           41
# 9   2016   gen    False  Alabama           AL           1           41
# 10  2016   gen    False  Alabama           AL           1           41
# 11  2016   gen    False  Alabama           AL           1           41
# ...

# %%
df_s16.head()
# Out:
#    year stage  special    state state_postal  state_fips  state_icpsr  \
# 0  2016   gen    False  Alabama           AL           1           41
# 1  2016   gen    False  Alabama           AL           1           41
# 2  2016   gen    False  Alabama           AL           1           41
# 3  2016   gen    False  Alabama           AL           1           41
# 4  2016   gen    False  Alabama           AL           1           41
#
#       county_name  county_fips  county_ansi  ...  candidate_middle  \
# 0  Autauga County       1001.0     161526.0  ...               NaN
# 1  Autauga County       1001.0     161526.0  ...               NaN
# 2  Autauga County       1001.0     161526.0  ...               NaN
# 3  Autauga County       1001.0     161526.0  ...               NaN
# 4  Autauga County       1001.0     161526.0  ...                C.
#
#       candidate_full candidate_suffix candidate_nickname candidate_fec  \
# ...

# %%
cols_s = df_s16.columns.tolist()
cols_h = df_h16.columns.tolist()

# %%
len(cols_h)
# Out:
# 37

# %%
cols_h == cols_s
# Out:
# True

# %%
df_16 = pd.concat([df_s16,df_h16])

# %%
df_16.shape
cols_sh = df_16.columns.tolist()
cols_sh==cols_s
# Out:
# True

# %%
df_s16.shape[0]+df_h16.shape[0]
# Out:
# 2071684

# %%
df_16.rename(columns={"candidate_party":"party_detailed"},inplace=True)
#df_16['party_detailed'] = df_16['party_detailed'].fillna("Other")

# %%
df_16.loc[df_16["state"]=="Virginia"].to_csv("data/MIT_data_2016_HouseSenate_merged.csv")

# %%
df_16.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'party_detailed', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
set(df_h16["office"].tolist())
# Out:
# {'ALL UNOPPOSED CANDIDATES',
#  'All Unopposed Candidates',
#  'Straight Party',
#  'Straight Ticket',
#  'Straight ticket',
#  'UNNOPPOSED CANDIDATES (UNION)',
#  'UNOPPOSED',
#  'UNOPPOSED CANDIDATES',
#  'UNOPPOSED DEMOCRATIC CANDIDATES',
#  'UNOPPOSED INDEPENDENT CANDIDATES',
#  'UNOPPOSED REPUBLICAN CANDIDATES',
#  'US House',
#  'Unopposed Candidates'}

# %%
df_16['party_detailed']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4          Republican
#               ...
# 1127510      Democrat
# 1127511    Republican
# 1127512      Democrat
# 1127513    Republican
# 1127514      Democrat
# Name: party_detailed, Length: 2071684, dtype: object

# %%
df_h16.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'candidate_party', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
df_s16.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'candidate_party', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
set(df_h16['candidate_party'].tolist())
# Out:
# {'Democrat', 'Republican', nan}

# %%
set(df_s16['candidate_party'].tolist())
# Out:
# {'Democrat', 'Republican', nan}

# %%
set(df_16['party_detailed'].tolist())

# %%
set(df_h16['party'].tolist())

# %%
php = df_h16['party'].tolist()
phc = df_h16['candidate_party'].tolist()
p = zip(php,phc)
dems = set()
repubs = set()
other = set()
for pi in p:
    if pi[1] == "Democrat":
        dems.add(pi[0])
    elif pi[1] == "Republican":
        repubs.add(pi[0])
    else:
        other.add(pi[0])

# %%
set(df_16['office'].tolist())
# Out:
# {'ALL UNOPPOSED CANDIDATES',
#  'All Unopposed Candidates',
#  'Straight Party',
#  'Straight Ticket',
#  'Straight ticket',
#  'UNNOPPOSED CANDIDATES (UNION)',
#  'UNOPPOSED',
#  'UNOPPOSED CANDIDATES',
#  'UNOPPOSED DEMOCRATIC CANDIDATES',
#  'UNOPPOSED INDEPENDENT CANDIDATES',
#  'UNOPPOSED REPUBLICAN CANDIDATES',
#  'US House',
#  'US Senate',
#  'Unopposed Candidates'}

# %%
df_16_va =df_16.loc[df_16["state"]=="Virginia"] 
set(df_16_va['office'].tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-ebf84513dcef> in <module>
# ----> 1 df_16_va =df_16.loc[df_16["state"].lower()=="Virginia"]
#       2 set(df_16_va['office'].tolist())
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
set(df_16["state"].tolist())
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming'}

# %%
file = "data/MIT_data_2016_HouseSenate_merged.csv"
df=pd.read_csv(file)
set(df["office"].tolist())
# Out:
# {'US House'}
